# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

df = pd.read_csv('Task (1) Dataset.csv')

# %%
df.head()
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# 0                Employee              1-2yr           Automobile
# 1                Employee         Above 10yr  Public (> 45 seats)
# 2                Employee              1-2yr      Lorry (41?100Q)
# 3                Employee             5-10yr  Public (> 45 seats)
# 4                Employee              2-5yr                  NaN
#
#   Owner_of_vehicle Service_year_of_vehicle  ... Vehicle_movement  \
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               914
# Vehicle_driver_relation         708
# Driving_experience             1026
# Type_of_vehicle                1178
# Owner_of_vehicle                596
# Service_year_of_vehicle        4883
# Defect_of_vehicle              5504
# Area_accident_occured           297
# Lanes_or_Medians                480
# Road_allignment                 173
# Types_of_Junction               887
# Road_surface_type               208
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               195
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                393
# Casualty_class                    0
# Sex_of_casualty                   1
# Age_band_of_casualty              1
# ...

# %%
columns_drop = ['Defect_of_vehicle', 'Service_year_of_vehicle', 'Work_of_casuality', 'Fitness_of_casuality']
df = df.drop(columns=columns_drop)
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               914
# Vehicle_driver_relation         708
# Driving_experience             1026
# Type_of_vehicle                1178
# Owner_of_vehicle                596
# Area_accident_occured           297
# Lanes_or_Medians                480
# Road_allignment                 173
# Types_of_Junction               887
# Road_surface_type               208
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               195
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                393
# Casualty_class                    0
# Sex_of_casualty                   1
# Age_band_of_casualty              1
# Casualty_severity                 1
# Pedestrian_movement               1
# ...

# %%
df['Educational_level'].fillna(df['Educational_level'].mode()[0], inplace=True)
df['Vehicle_driver_relation'].fillna(df['Vehicle_driver_relation'].mode()[0], inplace=True)
df['Driving_experience'].fillna(df['Driving_experience'].mode()[0], inplace=True)
df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode()[0], inplace=True)
df['Owner_of_vehicle'].fillna(df['Owner_of_vehicle'].mode()[0], inplace=True)
df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode()[0], inplace=True)
df['Lanes_or_Medians'].fillna(df['Lanes_or_Medians'].mode()[0], inplace=True)
df['Road_allignment'].fillna(df['Road_allignment'].mode()[0], inplace=True)
df['Types_of_Junction'].fillna(df['Types_of_Junction'].mode()[0], inplace=True)
df['Road_surface_type'].fillna(df['Road_surface_type'].mode()[0], inplace=True)
df['Type_of_collision'].fillna(df['Type_of_collision'].mode()[0], inplace=True)
df['Vehicle_movement'].fillna(df['Vehicle_movement'].mode()[0], inplace=True)
df['Sex_of_casualty'].fillna(df['Sex_of_casualty'].mode()[0], inplace=True)
df['Age_band_of_casualty'].fillna(df['Age_band_of_casualty'].mode()[0], inplace=True)
df['Casualty_severity'].fillna(df['Casualty_severity'].mode()[0], inplace=True)
df['Pedestrian_movement'].fillna(df['Pedestrian_movement'].mode()[0], inplace=True)
df['Cause_of_accident'].fillna(df['Cause_of_accident'].mode()[0], inplace=True)
df['Accident_severity'].fillna(df['Accident_severity'].mode()[0], inplace=True)
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Pedestrian_movement            0
# Cause_of_accident              0
# Accident_severity              0
# dtype: int64

# %%
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = df.select_dtypes(include=['object']).columns

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
# Example corrections for specific columns (adjust based on actual inconsistencies found)
df['Age_band_of_driver'] = df['Age_band_of_driver'].str.strip().str.lower()
df['Type_of_vehicle'] = df['Type_of_vehicle'].str.strip().str.lower()
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace({'automobile': 'car','public (> 45 seats)': 'bus','lorry (41?100q)': 'lorry (41-100q)'})
df['Area_accident_occured'] = df['Area_accident_occured'].str.strip().str.lower()

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
df.describe()
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count      15314       15314              15314         15314
# unique      1074           7                  6             4
# top     15:30:00      Friday              18-30          Male
# freq         140        2505               5192         14212
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                15314                   15314              15314
# unique                   8                       5                  8
# top     Junior high school                Employee             5-10yr
# freq                 10381                   12654               5222
#
#        Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# count            15314            15314                 15314  ...
# unique              18                5                    14  ...
# top                car            Owner                 other  ...
# ...

# %%
df.tail()
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 15309  16:15:00   Wednesday              31-50          Male
# 15310  18:00:00      Sunday            unknown          Male
# 15311  13:55:00      Sunday            over 51          Male
# 15312  13:55:00      Sunday              18-30        Female
# 15313  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 15309  Junior high school                Employee              2-5yr
# 15310   Elementary school                Employee             5-10yr
# 15311  Junior high school                Employee             5-10yr
# 15312  Junior high school                Employee         Above 10yr
# 15313  Junior high school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Area_accident_occured  ...  \
# 15309   lorry (11?40q)            Owner   outside rural areas  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15314 entries, 0 to 15313
# Data columns (total 28 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         15314 non-null  object
#  1   Day_of_week                  15314 non-null  object
#  2   Age_band_of_driver           15314 non-null  object
#  3   Sex_of_driver                15314 non-null  object
#  4   Educational_level            15314 non-null  object
#  5   Vehicle_driver_relation      15314 non-null  object
#  6   Driving_experience           15314 non-null  object
#  7   Type_of_vehicle              15314 non-null  object
#  8   Owner_of_vehicle             15314 non-null  object
#  9   Area_accident_occured        15314 non-null  object
#  10  Lanes_or_Medians             15314 non-null  object
#  11  Road_allignment              15314 non-null  object
#  12  Types_of_Junction            15314 non-null  object
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='Age_band_of_driver', order=df['Age_band_of_driver'].value_counts().index)
plt.title('Distribution of Age Band of Driver')
plt.xlabel('Age Band of Driver')
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Age_band_of_driver', hue='Accident_severity', data=df)
plt.title('Age Band of Driver vs. Accident Severity')
plt.xlabel('Age Band of Driver')
plt.ylabel('Accident_severity')
plt.legend(title='Accident Severity')
plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %%
plt.figure(figsize=(10, 10))
sns.countplot(y='Age_band_of_driver', data=df)
plt.show()

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
for col in categorical_cols:
    plt.figure(figsize=(10, 5))
    sns.countplot(y=col, data=df)
    plt.show()

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>
